# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Preparing training data

# %%
df_train = pd.read_csv(r'G:\Coding ninjas\Kaggle projects & submissions\house-prices-advanced-regression-techniques\train.csv')
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
missing = df_train.isnull().sum().sort_values(ascending = False)
missing
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# FireplaceQu     690
#                ...
# ExterQual         0
# Exterior2nd       0
# Exterior1st       0
# RoofMatl          0
# SalePrice         0
# Length: 81, dtype: int64

# %%
missing_features = missing.index
missing_values = missing.values

d={}
for i in range(len(missing)):
    if missing_values[i] != 0:
        d[missing_features[i]] = missing_values[i]
d
# Out:
# {'PoolQC': 1453,
#  'MiscFeature': 1406,
#  'Alley': 1369,
#  'Fence': 1179,
#  'FireplaceQu': 690,
#  'LotFrontage': 259,
#  'GarageYrBlt': 81,
#  'GarageCond': 81,
#  'GarageType': 81,
#  'GarageFinish': 81,
#  'GarageQual': 81,
#  'BsmtFinType2': 38,
#  'BsmtExposure': 38,
#  'BsmtQual': 37,
#  'BsmtCond': 37,
#  'BsmtFinType1': 37,
#  'MasVnrArea': 8,
#  'MasVnrType': 8,
#  'Electrical': 1}

# %%
#since out of 1460 there are more than 1000 values missing so we are gonna drop these features
df_train.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence'], axis =1, inplace = True)

# %%
df_train['LotFrontage'].isnull().sum()
# Out:
# 259

# %%
df_train['LotFrontage'].fillna(df_train['LotFrontage'].mean(), inplace = True)
df_train['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
df_train.drop(['Id', 'GarageYrBlt'], axis = 1, inplace = True)

# %%
df_train['GarageCond'].value_counts()
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
df_train['GarageCond'].fillna(df_train['GarageCond'].mode().values[0], inplace = True)
df_train['GarageCond'].isnull().sum()
# Out:
# 0

# %%
df_train['GarageQual'].value_counts()
# Out:
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64

# %%
df_train['GarageQual'].fillna(df_train['GarageQual'].mode().values[0], inplace = True)
df_train['GarageQual'].isnull().sum()
# Out:
# 0

# %%
df_train['BsmtFinType2'].value_counts()
# Out:
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64

# %%
df_train['BsmtFinType2'].fillna(df_train['BsmtFinType2'].mode().values[0], inplace = True)
df_train['BsmtFinType2'].isnull().sum()
# Out:
# 0

# %%
df_train['BsmtExposure'].value_counts()
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
df_train['BsmtExposure'].fillna(df_train['BsmtExposure'].mode().values[0], inplace = True)
df_train['BsmtExposure'].isnull().sum()
# Out:
# 0

# %%
df_train['BsmtQual'].value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
df_train['BsmtQual'].fillna(df_train['BsmtQual'].mode().values[0], inplace = True)
df_train['BsmtQual'].isnull().sum()
# Out:
# 0

# %%
df_train['BsmtCond'].value_counts()
# Out:
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64

# %%
df_train['BsmtCond'].fillna(df_train['BsmtQual'].mode().values[0], inplace = True)
df_train['BsmtQual'].isnull().sum()
# Out:
# 0

# %%
df_train['BsmtFinType1'].value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
df_train['BsmtFinType1'].fillna(df_train['BsmtFinType1'].mode().values[0], inplace = True)
df_train['BsmtFinType1'].isnull().sum()
# Out:
# 0

# %%
df_train['MasVnrArea'].fillna(df_train['MasVnrArea'].mode().values[0], inplace = True)
df_train['MasVnrArea'].isnull().sum()
# Out:
# 0

# %%
df_train['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df_train['MasVnrType'].fillna(df_train['MasVnrType'].mode().values[0], inplace = True)
df_train['MasVnrType'].isnull().sum()
# Out:
# 0

# %%
df_train['Electrical'].value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
df_train['Electrical'].fillna(df_train['Electrical'].mode().values[0], inplace = True)
df_train['Electrical'].isnull().sum()
# Out:
# 0

# %%
df_train['FireplaceQu'].value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
df_train['FireplaceQu'].fillna(df_train['FireplaceQu'].mode().values[0], inplace = True)
df_train['FireplaceQu'].isnull().sum()
# Out:
# 0

# %%
df_train['GarageType'].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
df_train['GarageType'].fillna(df_train['GarageType'].mode().values[0], inplace = True)
df_train['GarageType'].isnull().sum()
# Out:
# 0

# %%
df_train['GarageFinish'].value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %%
df_train['GarageFinish'].fillna(df_train['GarageFinish'].mode().values[0], inplace = True)
df_train['GarageFinish'].isnull().sum()
# Out:
# 0

# %%
df_train.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %%
columns=['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
         'Condition2','BldgType','Condition1','HouseStyle','SaleType',
        'SaleCondition','ExterCond',
         'ExterQual','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
        'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Heating','HeatingQC',
         'CentralAir',
         'Electrical','KitchenQual','Functional',
         'FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive']

len(columns)
# Out:
# 39

# %%
def category_dummy_cols(cols, df):
    i=0
    for fields in cols:
        print(fields)
        df1 = pd.get_dummies(df[fields], drop_first = True)
        
        if i==0:
            df_dummies = df1.copy()
        else:
            df_dummies = pd.concat([df_dummies, df1],axis=1)
        i=i+1
        
    return df_dummies

# %%
df_train_dummies = category_dummy_cols(columns, df_train)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition2
# BldgType
# Condition1
# HouseStyle
# SaleType
# SaleCondition
# ExterCond
# ExterQual
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive

# %%
df_train_dummies.columns
# Out:
# Index(['FV', 'RH', 'RL', 'RM', 'Pave', 'IR2', 'IR3', 'Reg', 'HLS', 'Low',
#        ...
#        'Fa', 'Gd', 'Po', 'TA', 'Fa', 'Gd', 'Po', 'TA', 'P', 'Y'],
#       dtype='object', length=200)

# %% [markdown]
# # Preparing testing data

# %%
df_test = pd.read_csv(r'G:\Coding ninjas\Kaggle projects & submissions\house-prices-advanced-regression-techniques\test.csv')
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
missing_te = df_test.isnull().sum().sort_values(ascending = False)
missing_te
# Out:
# PoolQC           1456
# MiscFeature      1408
# Alley            1352
# Fence            1169
# FireplaceQu       730
#                  ...
# Electrical          0
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# SaleCondition       0
# Length: 80, dtype: int64

# %%
missing_features_te = missing_te.index
missing_values_te = missing_te.values

dte={}
for i in range(len(missing_te)):
    if missing_values_te[i] != 0:
        dte[missing_features_te[i]] = missing_values_te[i]
dte
# Out:
# {'PoolQC': 1456,
#  'MiscFeature': 1408,
#  'Alley': 1352,
#  'Fence': 1169,
#  'FireplaceQu': 730,
#  'LotFrontage': 227,
#  'GarageYrBlt': 78,
#  'GarageQual': 78,
#  'GarageFinish': 78,
#  'GarageCond': 78,
#  'GarageType': 76,
#  'BsmtCond': 45,
#  'BsmtQual': 44,
#  'BsmtExposure': 44,
#  'BsmtFinType1': 42,
#  'BsmtFinType2': 42,
#  'MasVnrType': 16,
#  'MasVnrArea': 15,
#  'MSZoning': 4,
#  'BsmtHalfBath': 2,
#  'Utilities': 2,
#  'Functional': 2,
#  'BsmtFullBath': 2,
#  'BsmtFinSF1': 1,
#  'BsmtFinSF2': 1,
#  'BsmtUnfSF': 1,
#  'KitchenQual': 1,
#  'TotalBsmtSF': 1,
#  'Exterior2nd': 1,
#  'GarageCars': 1,
#  'Exterior1st': 1,
#  'GarageArea': 1,
#  'SaleType': 1}

# %%
df_test.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence'], axis =1, inplace = True)

# %%
df_test['LotFrontage'].fillna(df_test['LotFrontage'].mean(), inplace = True)
df_test.drop(['Id', 'GarageYrBlt'], axis = 1, inplace = True)
df_test['GarageCond'].fillna(df_test['GarageCond'].mode().values[0], inplace = True)
df_test['GarageQual'].fillna(df_test['GarageQual'].mode().values[0], inplace = True)
df_test['BsmtFinType2'].fillna(df_test['BsmtFinType2'].mode().values[0], inplace = True)
df_test['BsmtExposure'].fillna(df_test['BsmtExposure'].mode().values[0], inplace = True)
df_test['BsmtQual'].fillna(df_test['BsmtQual'].mode().values[0], inplace = True)
df_test['BsmtCond'].fillna(df_test['BsmtQual'].mode().values[0], inplace = True)
df_test['BsmtFinType1'].fillna(df_test['BsmtFinType1'].mode().values[0], inplace = True)
df_test['MasVnrArea'].fillna(df_test['MasVnrArea'].mode().values[0], inplace = True)
df_test['MasVnrType'].fillna(df_test['MasVnrType'].mode().values[0], inplace = True)
df_test['Electrical'].fillna(df_test['Electrical'].mode().values[0], inplace = True)
df_test['FireplaceQu'].fillna(df_test['FireplaceQu'].mode().values[0], inplace = True)
df_test['GarageType'].fillna(df_test['GarageType'].mode().values[0], inplace = True)
df_test['GarageFinish'].fillna(df_test['GarageFinish'].mode().values[0], inplace = True)

# %%
df_test.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         4
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        2
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      1
# Exterior2nd      1
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       1
# BsmtFinType2     0
# BsmtFinSF2       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     2
# BsmtHalfBath     2
# ...

# %%
df_test['MSZoning'].fillna(df_test['MSZoning'].mode().values[0], inplace = True)
df_test['Utilities'].fillna(df_test['Utilities'].mode().values[0], inplace = True)
df_test['Exterior1st'].fillna(df_test['Exterior1st'].mode().values[0], inplace = True)
df_test['Exterior2nd'].fillna(df_test['Exterior2nd'].mode().values[0], inplace = True)
df_test['BsmtFinSF1'].fillna(df_test['BsmtFinSF1'].mode().values[0], inplace = True)
df_test['BsmtFinSF2'].fillna(df_test['BsmtFinSF2'].mode().values[0], inplace = True)
df_test['BsmtFinSF2'].fillna(df_test['BsmtFinSF2'].mode().values[0], inplace = True)
df_test['BsmtUnfSF'].fillna(df_test['BsmtUnfSF'].mode().values[0], inplace = True)
df_test['TotalBsmtSF'].fillna(df_test['TotalBsmtSF'].mode().values[0], inplace = True)
df_test['BsmtFullBath'].fillna(df_test['BsmtFullBath'].mode().values[0], inplace = True)
df_test['BsmtFullBath'].fillna(df_test['BsmtFullBath'].mode().values[0], inplace = True)
df_test['BsmtHalfBath'].fillna(df_test['BsmtHalfBath'].mode().values[0], inplace = True)
df_test['KitchenQual'].fillna(df_test['KitchenQual'].mode().values[0], inplace = True)
df_test['Functional'].fillna(df_test['Functional'].mode().values[0], inplace = True)
df_test['GarageCars'].fillna(df_test['GarageCars'].mode().values[0], inplace = True)
df_test['GarageArea'].fillna(df_test['GarageArea'].mode().values[0], inplace = True)
df_test['SaleType'].fillna(df_test['SaleType'].mode().values[0], inplace = True)

# %%
df_test.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# ...

# %%
df_test_dummies = category_dummy_cols(columns, df_test)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition2
# BldgType
# Condition1
# HouseStyle
# SaleType
# SaleCondition
# ExterCond
# ExterQual
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive

# %%
df_test_dummies.columns
# Out:
# Index(['FV', 'RH', 'RL', 'RM', 'Pave', 'IR2', 'IR3', 'Reg', 'HLS', 'Low',
#        ...
#        'Unf', 'Gd', 'Po', 'TA', 'Fa', 'Gd', 'Po', 'TA', 'P', 'Y'],
#       dtype='object', length=184)

# %% [markdown]
# # as we can see that there is a difference between training & testing dummy columns so we will combine training & testing data & then apply label encoding

# %%
df = pd.concat([df_train, df_test], axis = 0)
df.shape
# Out:
# (2919, 75)

# %%
df_dummies = category_dummy_cols(columns, df)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition2
# BldgType
# Condition1
# HouseStyle
# SaleType
# SaleCondition
# ExterCond
# ExterQual
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive

# %%
df_dummies.columns
# Out:
# Index(['FV', 'RH', 'RL', 'RM', 'Pave', 'IR2', 'IR3', 'Reg', 'HLS', 'Low',
#        ...
#        'Fa', 'Gd', 'Po', 'TA', 'Fa', 'Gd', 'Po', 'TA', 'P', 'Y'],
#       dtype='object', length=200)

# %%
df.drop(columns, axis = 1, inplace = True)
df_final = pd.concat([df, df_dummies], axis = 1)
df_final.shape
# Out:
# (2919, 236)

# %%
df_final = df_final.loc[:, ~df_final.columns.duplicated()]

# %%
df_final.shape
# Out:
# (2919, 176)

# %%
df_final.to_csv('housing_price_cleaned.csv', index=False)
